# %% [markdown]
# ##  Materials associated with the paper:
#
# Cao, W., Williams, S., Flament, N., Zahirovic, S., Scotese, C., and Müller, R. D., 2018. Paleolatitudinal distribution of lithologic indicators of climate in a paleogeographic framework. Geological Magazine, 1-24. doi:10.1017/S0016756818000110.
#
# ### This Jupyter notebook is used to generate Figure 11 in the paper
#
# The code in this notebook is written in Python 2.7. It utilises the standard scientific Python modules including numpy, pandas, matplotlib, os and the open source modules pygplates which provides a Python API to the GPlates software (https://www.gplates.org/).

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.ticker import MultipleLocator, FormatStrFormatter
import os
# %matplotlib inline

# %%
##############################################
# Matthews2016 model, bin size: 5 degree
# Coals
data_coals_raw_Matthews2016 = pd.read_excel('/Users/wenchaocao/Research/41_Paleobiology_Paleotectonics/9_3_LithData_TwoBiasRemoved_CorrectedBeforeFlipping_Doubled/Coals_Matthews2016_TwoBiasRemoved_CorrectedBeforeFlipping_Flipped_Doubled_BinningSize5_Normalised.xlsx')
data_Matthews2016 = np.array(data_coals_raw_Matthews2016)

# Evaporites
#data_raw_Matthews2016 = pd.read_excel('/Users/wenchaocao/Research/41_Paleobiology_Paleotectonics/9_3_LithData_TwoBiasRemoved_CorrectedBeforeFlipping_Doubled/Evaporites_Matthews2016_TwoBiasRemoved_CorrectedBeforeFlipping_Flipped_Doubled.xlsx')
#data_Matthews2016 = np.array(data_raw_Matthews2016)

# Glacial
#data_raw_Matthews2016 = pd.read_excel('/Users/wenchaocao/Research/41_Paleobiology_Paleotectonics/9_3_LithData_TwoBiasRemoved_CorrectedBeforeFlipping_Doubled/Glacial_Matthews2016_TwoBiasRemoved_CorrectedBeforeFlipping_Flipped_Doubled.xlsx')
#data_Matthews2016 = np.array(data_raw_Matthews2016)


##############################################
# Scotese2008 model, binning size; 5 degree
# Coals
data_coals_raw_Scotese2008= pd.read_excel('/Users/wenchaocao/Research/41_Paleobiology_Paleotectonics/9_3_LithData_TwoBiasRemoved_CorrectedBeforeFlipping_Doubled/Coals_Scotese2008_TwoBiasRemoved_CorrectedBeforeFlipping_Flipped_Doubled_BinningSize5_Normarlised.xlsx')
data_Scotese2008 = np.array(data_coals_raw_Scotese2008)

# Evaporites
#data_raw_Scotese2008 = pd.read_excel('/Users/wenchaocao/Research/41_Paleobiology_Paleotectonics/9_3_LithData_TwoBiasRemoved_CorrectedBeforeFlipping_Doubled/Evaporites_Scotese2008_TwoBiasRemoved_CorrectedBeforeFlipping_Flipped_Doubled.xlsx')
#data_Scotese2008 = np.array(data_raw_Scotese2008)

# Glacial
#data_raw_Scotese2008 = pd.read_excel('/Users/wenchaocao/Research/41_Paleobiology_Paleotectonics/9_3_LithData_TwoBiasRemoved_CorrectedBeforeFlipping_Doubled/Glacial_Scotese2008_TwoBiasRemoved_CorrectedBeforeFlipping_Flipped_Doubled.xlsx')
#data_Scotese2008 = np.array(data_raw_Scotese2008)

# %%
fig, axes = plt.subplots(nrows=24, ncols=1,figsize=(4, 36))

for i in np.arange(0,24,1):
    
    result = []
    
    xedges = np.arange(-180, 181, 5) #longtitude
    yedges = np.arange(-90, 91, 5) #latitude, specify the bin size    
    
    # Coals, evaporites and glacial deposits
    axes[23-i].bar(np.array(yedges[:-1]), data_Matthews2016[:,i], width=5, color='blue',linewidth=0.5,alpha=0.3) #edgecolor='grey',
    axes[23-i].bar(np.array(yedges[:-1]), data_Scotese2008[:,i], width=5, color='red',linewidth=0.5,alpha=0.3) #edgecolor='grey',
    
    axes[23-i].set_xticks(np.arange(-90, 91, 10))
    axes[23-i].set_xticklabels([])
    axes[23-i].set_xlim((90,-90))
    axes[23-i].set_ylim(ymin=0)
    axes[23-i].xaxis.set_tick_params(direction='out') #labelsize=12,
    #plt.setp(axes[i].get_xticklabels(), fontsize=12.) #,rotation=50

    axes[23-i].yaxis.set_tick_params(labelsize=14,direction='out') #
    axes[23-i].xaxis.set_ticks_position('top') # bottom
    axes[23-i].set_yticks(axes[23-i].get_yticks()[::2]) # set the major ticks
    interval = np.diff(axes[23-i].get_yticks())[0]
    axes[23-i].yaxis.set_minor_locator(MultipleLocator(interval/2))
    axes[23-i].tick_params(which = 'both', direction = 'out') # if only want to set y-axis: axes[1,2].yaxis.set_tick_params(labelsize=12,direction='out')
    axes[23-i].yaxis.set_ticks_position('left')

fig.subplots_adjust(hspace=0.00)
plt.savefig('Coal_Doubled_TwoRecons_BinSize5.pdf',dpi=600)
plt.show
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-12-219ba3ebcba0> in <module>()
#      10     # Coals, evaporites and glacial deposits
#      11     axes[23-i].bar(np.array(yedges[:-1]), data_Matthews2016[:,i], width=5, color='blue',linewidth=0.5,alpha=0.3) #edgecolor='grey',
# ---> 12     axes[23-i].bar(np.array(yedges[:-1]), data_Scotese2008[:,i], width=5, color='red',linewidth=0.5,alpha=0.3) #edgecolor='grey',
#      13
#      14     axes[23-i].set_xticks(np.arange(-90, 91, 10))
#
# /Users/wenchaocao/anaconda/lib/python2.7/site-packages/matplotlib/__init__.pyc in inner(ax, *args, **kwargs)
#    1810                     warnings.warn(msg % (label_namer, func.__name__),
#    1811                                   RuntimeWarning, stacklevel=2)
# -> 1812             return func(ax, *args, **kwargs)
#    1813         pre_doc = inner.__doc__
# ...

# %% [markdown]
# ### 2. Plot different binning size results

# %% [markdown]
# ### 5 degree

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.ticker import MultipleLocator, FormatStrFormatter
import os

# %matplotlib inline

##############################################
# Matthews2016 model, bin size: 5 degree
# Coals
data_raw_Matthews2016 = pd.read_excel('/Users/wenchaocao/Research/41_Paleobiology_Paleotectonics/9_3_LithData_TwoBiasRemoved_CorrectedBeforeFlipping_Doubled/Coals_Matthews2016_TwoBiasRemoved_CorrectedBeforeFlipping_Flipped_Doubled_BinningSize5_Normalised.xlsx')
data_Matthews2016_BinningSize5 = np.array(data_raw_Matthews2016)

# Evaporites
#data_raw_Matthews2016 = pd.read_excel('/Users/wenchaocao/Research/41_Paleobiology_Paleotectonics/9_3_LithData_TwoBiasRemoved_CorrectedBeforeFlipping_Doubled/Evaporites_Matthews2016_TwoBiasRemoved_CorrectedBeforeFlipping_Flipped_Doubled.xlsx')
#data_Matthews2016_BinningSize5 = np.array(data_raw_Matthews2016)

# Glacial
#data_raw_Matthews2016 = pd.read_excel('/Users/wenchaocao/Research/41_Paleobiology_Paleotectonics/9_3_LithData_TwoBiasRemoved_CorrectedBeforeFlipping_Doubled/Glacial_Matthews2016_TwoBiasRemoved_CorrectedBeforeFlipping_Flipped_Doubled.xlsx')
#data_Matthews2016_BinningSize5 = np.array(data_raw_Matthews2016)

#######################
# Matthews2016 model, bin size: 10 degree
# Coals
data_raw_Matthews2016 = pd.read_excel('/Users/wenchaocao/Research/41_Paleobiology_Paleotectonics/9_3_LithData_TwoBiasRemoved_CorrectedBeforeFlipping_Doubled/Coals_Matthews2016_TwoBiasRemoved_CorrectedBeforeFlipping_Flipped_Doubled_BinningSize10_Normalised.xlsx')
data_Matthews2016_BinningSize10 = np.array(data_raw_Matthews2016)

# Evaporites
#data_raw_Matthews2016 = pd.read_excel('/Users/wenchaocao/Research/41_Paleobiology_Paleotectonics/9_3_LithData_TwoBiasRemoved_CorrectedBeforeFlipping_Doubled/Evaporites_Matthews2016_TwoBiasRemoved_CorrectedBeforeFlipping_Flipped_Doubled_BinningSize10.xlsx')
#data_Matthews2016_BinningSize10 = np.array(data_raw_Matthews2016)

# Glacial
#data_raw_Matthews2016 = pd.read_excel('/Users/wenchaocao/Research/41_Paleobiology_Paleotectonics/9_3_LithData_TwoBiasRemoved_CorrectedBeforeFlipping_Doubled/Glacial_Matthews2016_TwoBiasRemoved_CorrectedBeforeFlipping_Flipped_Doubled_BinningSize10.xlsx')
#data_Matthews2016_BinningSize10 = np.array(data_raw_Matthews2016)


#######################
# Matthews2016 model, bin size: 2 degree
# Coals
data_coals_raw_Matthews2016 = pd.read_excel('/Users/wenchaocao/Research/41_Paleobiology_Paleotectonics/9_3_LithData_TwoBiasRemoved_CorrectedBeforeFlipping_Doubled/Coals_Matthews2016_TwoBiasRemoved_CorrectedBeforeFlipping_Flipped_Doubled_BinningSize2_Normalised.xlsx')
data_Matthews2016_BinningSize2 = np.array(data_coals_raw_Matthews2016)

# Evaporites
#data_raw_Matthews2016 = pd.read_excel('/Users/wenchaocao/Research/41_Paleobiology_Paleotectonics/9_3_LithData_TwoBiasRemoved_CorrectedBeforeFlipping_Doubled/Evaporites_Matthews2016_TwoBiasRemoved_CorrectedBeforeFlipping_Flipped_Doubled_BinningSize2.xlsx')
#data_Matthews2016_BinningSize2 = np.array(data_raw_Matthews2016)

# Glacial
#data_raw_Matthews2016 = pd.read_excel('/Users/wenchaocao/Research/41_Paleobiology_Paleotectonics/9_3_LithData_TwoBiasRemoved_CorrectedBeforeFlipping_Doubled/Glacial_Matthews2016_TwoBiasRemoved_CorrectedBeforeFlipping_Flipped_Doubled_BinningSize2.xlsx')
#data_Matthews2016_BinningSize2 = np.array(data_raw_Matthews2016)

# %%
fig, axes = plt.subplots(nrows=24, ncols=1,figsize=(4, 36))

for i in np.arange(0,24,1):
    
    ################################################
    # binning size: 5 degree
    xedges = np.arange(-180, 181, 5) #longtitude
    yedges = np.arange(-90, 91, 5) #latitude, specify the bin size

    # Coals, evaporites and glacial deposits
    axes[23-i].bar(np.array(yedges[:-1]), data_Matthews2016_BinningSize5[:,i], width=5, color='lightgrey') #,linewidth=0.5, edgecolor='grey', ,alpha=0.4
    
    axes[23-i].set_xticks(np.arange(-90, 91, 30))
    axes[23-i].set_xticklabels([])
    axes[23-i].set_xlim((90,-90))
    axes[23-i].set_ylim(ymin=0)
    #axes[23-i].set_ylim((0,0.014))
    axes[23-i].xaxis.set_tick_params(direction='out') #labelsize=12,
    #plt.setp(axes[i].get_xticklabels(), fontsize=12.) #,rotation=50
    axes[23-i].yaxis.set_tick_params(labelsize=14,direction='out') #
    axes[23-i].xaxis.set_ticks_position('top') # bottom
    axes[23-i].set_yticks(axes[23-i].get_yticks()[::2]) # set the major ticks
    interval = np.diff(axes[23-i].get_yticks())[0]
    axes[23-i].yaxis.set_minor_locator(MultipleLocator(interval/2))
    axes[23-i].tick_params(which = 'both', direction = 'out') # if only want to set y-axis: axes[1,2].yaxis.set_tick_params(labelsize=12,direction='out')
    axes[23-i].yaxis.set_ticks_position('left')
    
fig.subplots_adjust(hspace=0.00)
plt.savefig('Coals_Doubled_Matthews2016_BinSize5.pdf',dpi=600)
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %%
fig, axes = plt.subplots(nrows=24, ncols=1,figsize=(4, 36))

for i in np.arange(0,24,1):
    
    ################################################
    # binning size: 10 degree
    yedges_binningsize10 = np.arange(-90, 91, 10) #latitude, specify the bin size   

    # Coals, evaporites and glacial deposits
    axes[23-i].bar(np.array(yedges_binningsize10[:-1]), data_Matthews2016_BinningSize10[:,i], width=10, color='lightgrey') #,linewidth=0.5, edgecolor='grey',alpha=0.4
    
    axes[23-i].set_xticks(np.arange(-90, 91, 30))
    axes[23-i].set_xticklabels([])
    axes[23-i].set_xlim((90,-90))
    axes[23-i].set_ylim(ymin=0)
    axes[23-i].xaxis.set_tick_params(direction='out') #labelsize=12,
    #plt.setp(axes[i].get_xticklabels(), fontsize=12.) #,rotation=50

    axes[23-i].yaxis.set_tick_params(labelsize=14,direction='out') #
    axes[23-i].xaxis.set_ticks_position('top') # bottom
    axes[23-i].set_yticks(axes[23-i].get_yticks()[::2]) # set the major ticks
    interval = np.diff(axes[23-i].get_yticks())[0]
    axes[23-i].yaxis.set_minor_locator(MultipleLocator(interval/2))
    axes[23-i].tick_params(which = 'both', direction = 'out') # if only want to set y-axis: axes[1,2].yaxis.set_tick_params(labelsize=12,direction='out')
    axes[23-i].yaxis.set_ticks_position('left')

fig.subplots_adjust(hspace=0.00)
plt.savefig('Coals_Doubled_Matthews2016_BinSize10.pdf',dpi=600)
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %%
fig, axes = plt.subplots(nrows=24, ncols=1,figsize=(4, 36))

for i in np.arange(0,24,1):
    
    ################################################
    # binning size: 5 degree
    xedges = np.arange(-180, 181, 5) #longtitude
    yedges_binningsize2 = np.arange(-90, 91, 2)
    
    # Coals, evaporites and glacial deposits
    axes[23-i].bar(np.array(yedges_binningsize2[:-1]), data_Matthews2016_BinningSize2[:,i], width=2, color='lightgrey') #,linewidth=0.5,edgecolor='grey',alpha=0.4
    
    axes[23-i].set_xticks(np.arange(-90, 91, 30))
    axes[23-i].set_xticklabels([])
    axes[23-i].set_xlim((90,-90))
    axes[23-i].set_ylim(ymin=0)
    axes[23-i].xaxis.set_tick_params(direction='out') #labelsize=12,
    #plt.setp(axes[i].get_xticklabels(), fontsize=12.) #,rotation=50

    axes[23-i].yaxis.set_tick_params(labelsize=14,direction='out') #
    axes[23-i].xaxis.set_ticks_position('top') # bottom
    axes[23-i].set_yticks(axes[23-i].get_yticks()[::2]) # set the major ticks
    interval = np.diff(axes[23-i].get_yticks())[0]
    axes[23-i].yaxis.set_minor_locator(MultipleLocator(interval/2))
    axes[23-i].tick_params(which = 'both', direction = 'out') # if only want to set y-axis: axes[1,2].yaxis.set_tick_params(labelsize=12,direction='out')
    axes[23-i].yaxis.set_ticks_position('left')

fig.subplots_adjust(hspace=0.00)
plt.savefig('Coals_Doubled_Matthews2016_BinSize2.pdf',dpi=600)
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %% [markdown]
# ## Other codes not important

# %%
fig = plt.subplots(figsize=(24,4),tight_layout=True)

for i in np.arange(1,22,1):  #(40,211,50),np.arange(0,401,50)
    ax = plt.subplot(1,22,i+1)
    yedges = np.arange(-90, 91, 5) #latitude
    plt.barh(yedges[:-1]+2.5, data_coal[:,i:i+1], height=5, color='blue',alpha=0.5)
    plt.subplots_adjust(wspace=0)
    plt.setp(ax.get_yticklabels(),visible=False)
    plt.setp(ax.get_xticklabels(),visible=False)
    plt.ylim((-90,90))
    #plt.show()
#plt.savefig('Coal+Evaporite+T+D+G_and_Land_Distribution_Scotese2008_0-400Ma_Global_Step20_Pixel5x5.pdf')

# %% [markdown]
# ### Here trying to correct the land bias using Scotese's weighting factors

# %%
# weighting factor of Scotese2008
data_weighting_Scotese1990_raw = pd.read_csv('/Users/wenchaocao/Research/41_Paleobiology_Paleotectonics/Weighting_Factors_CorrectLandAreas.csv')
data_weighting_Scotese1990 = np.array(data_weighting_Scotese1990_raw)
#print data1[:,1:2]/data_2[:,2:3]

fig = plt.subplots(figsize=(24,4),tight_layout=True)

for i in np.arange(1,22,1):  #(40,211,50),np.arange(0,401,50)
    ax = plt.subplot(1,22,i+1)
    yedges = np.arange(-90, 91, 5) #latitude
    plt.barh(yedges[:-1]+2.5, data_coal[:,i:i+1]/data_weighting_Scotese1990[:,2:3], height=5, color='blue',alpha=0.5)
    plt.subplots_adjust(wspace=0)
    plt.setp(ax.get_yticklabels(),visible=False)
    plt.setp(ax.get_xticklabels(),visible=False)
    plt.ylim((-90,90))
    #plt.show()
#plt.savefig('Coal+Evaporite+T+D+G_and_Land_Distribution_Scotese2008_0-400Ma_Global_Step20_Pixel5x5.pdf')

# %% [markdown]
# ### Here try to correct the land bias using our weighting factors generated from land area

# %%
# weighting factor of Scotese2008
#data_weighting_Scotese2008_raw = pd.read_csv('/Users/wenchaocao/Research/41_Paleobiology_Paleotectonics/Weighting_Factors_CorrectLandAreas.csv')
#data_weighting_Scotese2008 = np.array(data_weighting_Scotese2008_raw)

# weighting factor of my data
data_weighting_raw = pd.read_csv('/Users/wenchaocao/Research/41_Paleobiology_Paleotectonics/2_CSV_Files_OnlyForMakingPlots/2_1_LandArea_InEachBand_Matthews2016Modified.csv')
data_weighting = np.array(data_weighting_raw)
#print data_weighting
#weighting = []

fig = plt.subplots(figsize=(24,4)) #figsize=(24,4),tight_layout=True

for i in np.arange(1,22,1):
    ax = plt.subplot(1,22,i+1)
    #print data_coal[:,i:i+1]
    #print data_weighting[:,i:i+1]
    #print np.float64(data_weighting[:,i:i+1])/np.max(data_weighting[:,i:i+1])
    relative_area = np.float64(data_weighting[:,i:i+1])/np.max(data_weighting[:,i:i+1])
    #print data_weighting_percent                                                      
    data_weighted = data_coal[:,i:i+1]/relative_area
    #print data_weighted

    plt.barh(yedges[:-1]+2.5,data_weighted, height=5, color='blue',alpha=0.5)

#for i in np.arange(1,22,1):
    
    #print data_weighting[:,i:i+1]
    #print np.sum(data_weighting[:,i:i+1])
    #weighting_array = np.array(weighting)
#print weighting_array.shape
    #print weighting_array[:,i-1:].shape
    
    #print data_coal[:,i:i+1].shape
    #print data_coal[:,i:i+1]/weighting_array[:,i-1:]
    #weighting_array[:,i:i+1]
    #print data_weighting[:,i+2:i+3]
    #print np.sum(data_weighting[:,i+2:i+3])
    #print weighting
# Out:
# /Users/wenchaocao/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:20: RuntimeWarning: invalid value encountered in divide

# %%
# weighting factor of my data
data_weighting_raw = pd.read_csv('/Users/wenchaocao/Research/41_Paleobiology_Paleotectonics/2_CSV_Files_OnlyForMakingPlots/2_1_LandArea_InEachBand_Matthews2016Modified.csv')
data_weighting = np.array(data_weighting_raw)

result = []
#fig = plt.subplots(figsize=(24,4))
for i in np.arange(1,12,1):  # set the time range here: np.arange(1,12,1):0-200Ma, 
    #ax = plt.subplot(1,22,i+1)
    #print data_coal[:,i:i+1]
    #print data_weighting[:,i:i+1]
    #print np.float64(data_weighting[:,i:i+1])/np.max(data_weighting[:,i:i+1])
    relative_area = np.float64(data_weighting[:,i:i+1])/np.max(data_weighting[:,i:i+1])
    #print data_weighting_percent
    #print relative_area
    for j in np.arange(0,36,1):
        #print relative_area[j]
        if relative_area[j] == 0:
            relative_area[j] = 0.0000000000000000000000001
    #print relative_area
    data_weighted = data_coal[:,i:i+1]/relative_area
    result.append(data_weighted)
#print result
result_1 = []
result_1 = np.sum(result,axis=0) # sum up data in Y-axis
print result_1
# Out:
# [[ 0.0709913 ]
#  [ 0.06615312]
#  [ 0.07005494]
#  [ 0.22782162]
#  [ 0.22094232]
#  [ 0.75885012]
#  [ 0.9726434 ]
#  [ 0.68745567]
#  [ 0.5885505 ]
#  [ 0.32242174]
#  [ 0.23029436]
#  [ 0.22731431]
#  [ 0.09895689]
#  [ 0.0910252 ]
#  [ 0.09602211]
#  [ 0.10679876]
#  [ 0.19371337]
#  [ 0.25974507]
#  [ 0.43313744]
#  [ 0.54823658]
#  [ 0.41323672]
#  [ 0.4190961 ]
#  [ 0.31630464]
#  [ 0.5343367 ]
#  [ 0.62531974]
#  [ 0.67145203]
#  [ 0.75400804]
#  [ 0.85254242]
#  [ 0.75884368]
#  [ 0.59929388]
#  [ 0.63203402]
#  [ 0.72835326]
#  [ 0.96797645]
#  [ 0.81745787]
#  [ 0.56555749]
#  [ 0.        ]]

# %%
fig = plt.figure(figsize=(10,4)) 
plt.bar(np.array(yedges[:-1]),result_1, width=5, color='blue',alpha=0.4) # yedges[:-1]), yedges[18:-1]
plt.xticks(np.arange(-90, 91, 10),size=12) 
plt.ylabel('Frequency',fontsize=16)
#plt.yxticks(size=12)
plt.xlim((-90,90))
#plt.ylim((0,150))
plt.grid()
#plt.title('Evaporite_Scotese2008_Global_Step20_BarChart_TwoHemi_0-200Ma', size=20) #Matthews2016 Scotese2008, Evaporite
#plt.savefig('Evaporite_Scotese2008_Global_Step20_BarChart_TwoHemi_0-200Ma.pdf')
