# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib
import pandas as pd
% matplotlib inline

# CO2
data_CO2 = pd.read_excel('/Users/wenchaocao/Research/41_Paleobiology_Paleotectonics/References_GM/Climate/Papers_FromSimon/ncomms14845-s3_copy.xlsx')
#data_CO2['lw95%']

# %%
fig, ax = plt.subplots(figsize=(8,4))
#ax.fill_between(data_max.iloc[:,0],0,data_max.iloc[:,1],facecolor='lightgrey',edgecolor='lightgrey',interpolate=True) #,alpha=0.8
#ax.fill_between(data_min.iloc[:,0],0,data_min.iloc[:,1],facecolor='white',edgecolor='white',interpolate=True)

ax.fill_between(data_CO2['Age (Ma)'],data_CO2['lw95%'],data_CO2['up95%'],facecolor='lightgrey',alpha=0.8,edgecolor='white',interpolate=True)
ax.fill_between(data_CO2['Age (Ma)'],data_CO2['lw68%'],data_CO2['up68%'],facecolor='grey',alpha=0.8,edgecolor='lightgrey',interpolate=True)

ax.plot(data_CO2['Age (Ma)'],data_CO2['pCO2 probability maximum'],c='blue', alpha=1)

#ax.scatter(data_ave.iloc[:,0],data_ave.iloc[:,1],c='black',edgecolors='black')

#ax.set_xticks(np.hstack((data['FromAge'],data['ToAge'])), rotation=50, size=8) #, rotation=50,,verticalalignment='top'
ax.set_ylabel('CO2 (ppm)', fontsize=16) 
ax.set_xlabel('Time (Ma)', fontsize=16) 
#plt.xlabel('Devonian     Carboniferous   Permian    Triassic     Jurassic   Cretaceous    Paleogene    Miocene', fontsize=16)
ax.set_xlim((419,0))
ax.set_ylim(ymin=0)
ax.xaxis.set_tick_params(direction='out')
ax.yaxis.set_tick_params(labelsize=14,direction='out')
ax.xaxis.set_ticks_position('bottom')
ax.yaxis.set_ticks_position('left')

plt.savefig('CO2.pdf')
